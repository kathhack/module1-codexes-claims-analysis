# %% [markdown]
# <a href="https://colab.research.google.com/github/kathhack/module1-codexes-claims-analysis/blob/main/INP_CMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !pip install pandas
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv',
                  sep='|')
###random sample
df.sample(10)
## look at a random sampple to check the validity of the data, making sure it looks right throughout the data set, not just the first and last 5 rows.
df.columns
# Out:
# ...
# <ipython-input-9-205f0255c733>:3: DtypeWarning: Columns (168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv',
# Index(['BENE_ID', 'CLM_ID', 'NCH_NEAR_LINE_REC_IDENT_CD', 'NCH_CLM_TYPE_CD',
#        'CLM_FROM_DT', 'CLM_THRU_DT', 'NCH_WKLY_PROC_DT', 'FI_CLM_PROC_DT',
#        'CLAIM_QUERY_CODE', 'PRVDR_NUM',
#        ...
#        'PRCDR_DT24', 'ICD_PRCDR_CD25', 'PRCDR_DT25', 'IME_OP_CLM_VAL_AMT',
#        'DSH_OP_CLM_VAL_AMT', 'CLM_UNCOMPD_CARE_PMT_AMT', 'CLM_LINE_NUM',
#        'REV_CNTR', 'HCPCS_CD', 'REV_CNTR_DDCTBL_COINSRNC_CD'],
#       dtype='object', length=197)

# %%
for i in df.columns:
    print(i)
#playing around with different views of the columns in the data
# Out:
# BENE_ID
# CLM_ID
# NCH_NEAR_LINE_REC_IDENT_CD
# NCH_CLM_TYPE_CD
# CLM_FROM_DT
# CLM_THRU_DT
# NCH_WKLY_PROC_DT
# FI_CLM_PROC_DT
# CLAIM_QUERY_CODE
# PRVDR_NUM
# CLM_FAC_TYPE_CD
# CLM_SRVC_CLSFCTN_TYPE_CD
# CLM_FREQ_CD
# FI_NUM
# CLM_MDCR_NON_PMT_RSN_CD
# CLM_PMT_AMT
# NCH_PRMRY_PYR_CLM_PD_AMT
# NCH_PRMRY_PYR_CD
# FI_CLM_ACTN_CD
# PRVDR_STATE_CD
# ORG_NPI_NUM
# AT_PHYSN_UPIN
# AT_PHYSN_NPI
# OP_PHYSN_UPIN
# OP_PHYSN_NPI
# OT_PHYSN_UPIN
# OT_PHYSN_NPI
# CLM_MCO_PD_SW
# PTNT_DSCHRG_STUS_CD
# CLM_PPS_IND_CD
# CLM_TOT_CHRG_AMT
# CLM_ADMSN_DT
# CLM_IP_ADMSN_TYPE_CD
# CLM_SRC_IP_ADMSN_CD
# NCH_PTNT_STATUS_IND_CD
# CLM_PASS_THRU_PER_DIEM_AMT
# NCH_BENE_IP_DDCTBL_AMT
# NCH_BENE_PTA_COINSRNC_LBLTY_AM
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM
# NCH_PROFNL_CMPNT_CHRG_AMT
# NCH_IP_NCVRD_CHRG_AMT
# NCH_IP_TOT_DDCTN_AMT
# CLM_TOT_PPS_CPTL_AMT
# CLM_PPS_CPTL_FSP_AMT
# CLM_PPS_CPTL_OUTLIER_AMT
# CLM_PPS_CPTL_DSPRPRTNT_SHR_AMT
# CLM_PPS_CPTL_IME_AMT
# CLM_PPS_CPTL_EXCPTN_AMT
# CLM_PPS_OLD_CPTL_HLD_HRMLS_AMT
# ...

# %%
for column in df.columns:
    print(column)
## printing all of the column headers in the data set
# Out:
# BENE_ID
# CLM_ID
# NCH_NEAR_LINE_REC_IDENT_CD
# NCH_CLM_TYPE_CD
# CLM_FROM_DT
# CLM_THRU_DT
# NCH_WKLY_PROC_DT
# FI_CLM_PROC_DT
# CLAIM_QUERY_CODE
# PRVDR_NUM
# CLM_FAC_TYPE_CD
# CLM_SRVC_CLSFCTN_TYPE_CD
# CLM_FREQ_CD
# FI_NUM
# CLM_MDCR_NON_PMT_RSN_CD
# CLM_PMT_AMT
# NCH_PRMRY_PYR_CLM_PD_AMT
# NCH_PRMRY_PYR_CD
# FI_CLM_ACTN_CD
# PRVDR_STATE_CD
# ORG_NPI_NUM
# AT_PHYSN_UPIN
# AT_PHYSN_NPI
# OP_PHYSN_UPIN
# OP_PHYSN_NPI
# OT_PHYSN_UPIN
# OT_PHYSN_NPI
# CLM_MCO_PD_SW
# PTNT_DSCHRG_STUS_CD
# CLM_PPS_IND_CD
# CLM_TOT_CHRG_AMT
# CLM_ADMSN_DT
# CLM_IP_ADMSN_TYPE_CD
# CLM_SRC_IP_ADMSN_CD
# NCH_PTNT_STATUS_IND_CD
# CLM_PASS_THRU_PER_DIEM_AMT
# NCH_BENE_IP_DDCTBL_AMT
# NCH_BENE_PTA_COINSRNC_LBLTY_AM
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM
# NCH_PROFNL_CMPNT_CHRG_AMT
# NCH_IP_NCVRD_CHRG_AMT
# NCH_IP_TOT_DDCTN_AMT
# CLM_TOT_PPS_CPTL_AMT
# CLM_PPS_CPTL_FSP_AMT
# CLM_PPS_CPTL_OUTLIER_AMT
# CLM_PPS_CPTL_DSPRPRTNT_SHR_AMT
# CLM_PPS_CPTL_IME_AMT
# CLM_PPS_CPTL_EXCPTN_AMT
# CLM_PPS_OLD_CPTL_HLD_HRMLS_AMT
# ...

# %%
##identifying code Claim Diagnosis E Code : The code used to identify the external cause of injury, poisoning, or other adverse effect.
df.ICD_DGNS_E_CD10
## first of 8 unique codes to explore for the assignment. Used the Data Dictionary from CMS to find the long name
## type: object
## there are no machine readable codes next to the numbers like there were in the class example, so nothing to look up here.
# Out:
# 0
# 1
# 2
# 3
# 4
#         ..
# 58061
# 58062
# 58063
# 58064
# 58065
# Name: ICD_DGNS_E_CD10, Length: 58066, dtype: object

# %%
#see how many times this code comes up
count = df.ICD_DGNS_E_CD10 ()
len(count)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b645c845f70d> in <cell line: 2>()
#       1 #see how many times this code comes up
# ----> 2 count = df.ICD_DGNS_E_CD10 ()
#       3 len(count)
#
# TypeError: 'Series' object is not callable

# %%
count = df.ICD_DGNS_E_CD10.unique()
len(count)
# Out:
# 1

# %%
##trying another code CLM_TOT_PPS_CPTL_AMT
df.CLM_TOT_PPS_CPTL_AMT
## no helpful codes to look up next to it.
## type: int64
## Claim PPS Capital Disproportionate Share Amount, The amount of disproportionate share (rate reflecting indigent population served) portion of the PPS payment for capital.
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 58061    0
# 58062    0
# 58063    0
# 58064    0
# 58065    0
# Name: CLM_TOT_PPS_CPTL_AMT, Length: 58066, dtype: int64

# %%
count = df.CLM_TOT_PPS_CPTL_AMT.unique()
len(count)
# Out:
# 1

# %%
df.CLM_UTLZTN_DAY_CNT
## Claim Medicare Utilization Day Count, On an institutional claim, the number of covered days of care that are chargeable to Medicare facility
  ##utilization that includes full days, coinsurance days, and lifetime reesrve days.
  ## type: NUM
##Not sure if my inpatient codes are not going to have machine readable alphanumerical codes like the DME examples do, will keep trying.
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 58061    6
# 58062    0
# 58063    0
# 58064    3
# 58065    0
# Name: CLM_UTLZTN_DAY_CNT, Length: 58066, dtype: int64

# %%
count = df.CLM_UTLZTN_DAY_CNT.unique()
len(count)
# Out:
# 45

# %%
df.CLM_ID
##having a hard time finding the meaning to these very large Claim Line numbers
## Claim Line Number, this variable identifies an individual line number on a claim
## type: NUM
# Out:
# 0       -10000930037831
# 1       -10000930038030
# 2       -10000930038031
# 3       -10000930038162
# 4       -10000930038162
#               ...
# 58061   -10000931485965
# 58062   -10000931485967
# 58063   -10000931485969
# 58064   -10000931485971
# 58065   -10000931486024
# Name: CLM_ID, Length: 58066, dtype: int64

# %%
count = df.CLM_ID.unique()
len(count)
# Out:
# 20867

# %%
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv',
                  sep='|')
##but why now when I try to reset myself and look at the columns again, is it giving me a URL link to the document?
# Out:
# <ipython-input-17-468f75585851>:1: DtypeWarning: Columns (168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv',

# %%
## testing value counts
df['CLM_UTLZTN_DAY_CNT'].value_counts()
## no data codes to look up to mirror the example from class
# Out:
# CLM_UTLZTN_DAY_CNT
# 0      42934
# 1       3455
# 2       1145
# 4       1090
# 5       1052
# 6       1034
# 3        896
# 9        891
# 7        872
# 8        750
# 10       714
# 14       641
# 12       603
# 13       596
# 11       514
# 18       166
# 15       152
# 16       115
# 25        79
# 21        77
# 17        74
# 22        55
# 23        34
# 20        33
# 29        32
# 19        11
# 32         7
# 26         5
# 24         5
# 36         5
# 27         4
# 28         4
# 31         3
# 64         2
# 39         2
# 34         2
# 104        2
# 30         2
# 45         2
# 43         1
# 40         1
# 50         1
# 37         1
# 47         1
# 33         1
# Name: count, dtype: int64

# %%
df['CLM_UTLZTN_DAY_CNT'].describe()
## instead of .value, use .describe to give us the descriptive statistics for a particular column
## count is the number of rows it's using to generate these descriptive stats
## the number of covered days billable to Medicare
## the average number of days that can be covered by Medicare = 1.7
# Out:
# count    58066.000000
# mean         1.700272
# std          4.002500
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max        104.000000
# Name: CLM_UTLZTN_DAY_CNT, dtype: float64

# %%
df.columns
# Out:
# Index(['BENE_ID', 'CLM_ID', 'NCH_NEAR_LINE_REC_IDENT_CD', 'NCH_CLM_TYPE_CD',
#        'CLM_FROM_DT', 'CLM_THRU_DT', 'NCH_WKLY_PROC_DT', 'FI_CLM_PROC_DT',
#        'CLAIM_QUERY_CODE', 'PRVDR_NUM',
#        ...
#        'PRCDR_DT24', 'ICD_PRCDR_CD25', 'PRCDR_DT25', 'IME_OP_CLM_VAL_AMT',
#        'DSH_OP_CLM_VAL_AMT', 'CLM_UNCOMPD_CARE_PMT_AMT', 'CLM_LINE_NUM',
#        'REV_CNTR', 'HCPCS_CD', 'REV_CNTR_DDCTBL_COINSRNC_CD'],
#       dtype='object', length=197)

# %%
for column in df.columns:
    print(column)
# Out:
# BENE_ID
# CLM_ID
# NCH_NEAR_LINE_REC_IDENT_CD
# NCH_CLM_TYPE_CD
# CLM_FROM_DT
# CLM_THRU_DT
# NCH_WKLY_PROC_DT
# FI_CLM_PROC_DT
# CLAIM_QUERY_CODE
# PRVDR_NUM
# CLM_FAC_TYPE_CD
# CLM_SRVC_CLSFCTN_TYPE_CD
# CLM_FREQ_CD
# FI_NUM
# CLM_MDCR_NON_PMT_RSN_CD
# CLM_PMT_AMT
# NCH_PRMRY_PYR_CLM_PD_AMT
# NCH_PRMRY_PYR_CD
# FI_CLM_ACTN_CD
# PRVDR_STATE_CD
# ORG_NPI_NUM
# AT_PHYSN_UPIN
# AT_PHYSN_NPI
# OP_PHYSN_UPIN
# OP_PHYSN_NPI
# OT_PHYSN_UPIN
# OT_PHYSN_NPI
# CLM_MCO_PD_SW
# PTNT_DSCHRG_STUS_CD
# CLM_PPS_IND_CD
# CLM_TOT_CHRG_AMT
# CLM_ADMSN_DT
# CLM_IP_ADMSN_TYPE_CD
# CLM_SRC_IP_ADMSN_CD
# NCH_PTNT_STATUS_IND_CD
# CLM_PASS_THRU_PER_DIEM_AMT
# NCH_BENE_IP_DDCTBL_AMT
# NCH_BENE_PTA_COINSRNC_LBLTY_AM
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM
# NCH_PROFNL_CMPNT_CHRG_AMT
# NCH_IP_NCVRD_CHRG_AMT
# NCH_IP_TOT_DDCTN_AMT
# CLM_TOT_PPS_CPTL_AMT
# CLM_PPS_CPTL_FSP_AMT
# CLM_PPS_CPTL_OUTLIER_AMT
# CLM_PPS_CPTL_DSPRPRTNT_SHR_AMT
# CLM_PPS_CPTL_IME_AMT
# CLM_PPS_CPTL_EXCPTN_AMT
# CLM_PPS_OLD_CPTL_HLD_HRMLS_AMT
# ...

# %%
df.CLM_FROM_DT
# Out:
# 0        25-Mar-2015
# 1        24-Sep-2015
# 2        09-May-2017
# 3        14-Jan-2017
# 4        14-Jan-2017
#             ...
# 58061    08-Jan-2020
# 58062    23-Oct-2020
# 58063    22-Aug-2021
# 58064    13-Sep-2021
# 58065    11-Jun-2017
# Name: CLM_FROM_DT, Length: 58066, dtype: object

# %%
df.CLM_TOT_CHRG_AMT
# Out:
# 0          96.65
# 1        6311.88
# 2        8545.72
# 3        1014.85
# 4        1014.85
#           ...
# 58061     166.97
# 58062     166.97
# 58063     166.97
# 58064     166.97
# 58065     166.97
# Name: CLM_TOT_CHRG_AMT, Length: 58066, dtype: float64

# %%
df.PRNCPAL_DGNS_CD
# Out:
# 0         S134XX
# 1          Z3480
# 2         T7432X
# 3         S8290X
# 4         S8290X
#           ...
# 58061    T50901A
# 58062    T50901A
# 58063    T50901A
# 58064    T50901A
# 58065     S93409
# Name: PRNCPAL_DGNS_CD, Length: 58066, dtype: object

# %%
df.ICD_DGNS_CD1
# Out:
# 0        S134XX
# 1        T7432X
# 2        T7432X
# 3        S8290X
# 4        S8290X
#           ...
# 58061    T7432X
# 58062      Z733
# 58063      Z608
# 58064      Z608
# 58065    S93409
# Name: ICD_DGNS_CD1, Length: 58066, dtype: object

# %%
df.CLM_E_POA_IND_SW11
# Out:
# 0
# 1
# 2
# 3
# 4
#         ..
# 58061
# 58062
# 58063
# 58064
# 58065
# Name: CLM_E_POA_IND_SW11, Length: 58066, dtype: object

# %%
df.HCPCS_CD
# Out:
# 0        99221
# 1        99221
# 2        99024
# 3        73610
# 4        29515
#          ...
# 58061    99221
# 58062    99221
# 58063    99221
# 58064    99221
# 58065    99221
# Name: HCPCS_CD, Length: 58066, dtype: object

# %%
df.ADMTG_DGNS_CD
#several NaN in the beginning, very different IDs in the end.
# Out:
# 0            NaN
# 1          Z3480
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 58061    T50901A
# 58062    T50901A
# 58063    T50901A
# 58064    T50901A
# 58065        NaN
# Name: ADMTG_DGNS_CD, Length: 58066, dtype: object

# %%
### random dample df.sample
df.ADMTG_DGNS_CD
df.sample(25)
# Out:
#               BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 2139  -10000010255804 -10000930085151                          V
# 3518  -10000010256420 -10000930108925                          V
# 42117 -10000010277590 -10000931079978                          V
# 4342  -10000010256656 -10000930120845                          V
# 51977 -10000010283209 -10000931298649                          V
# 39637 -10000010276075 -10000931005034                          V
# 38366 -10000010275307 -10000930966127                          V
# 39570 -10000010275985 -10000931000760                          V
# 2303  -10000010255799 -10000930085235                          V
# 26286 -10000010268778 -10000930663558                          V
# 28916 -10000010270749 -10000930742077                          V
# 11967 -10000010260059 -10000930282145                          V
# 34809 -10000010273616 -10000930883193                          V
# ...

# %%
## starting over following the helper starter code
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv',
                  sep='|')
data = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv')
print(data.head)
# Out:
# <ipython-input-99-f10741f8052f>:2: DtypeWarning: Columns (168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv',
# ...

# %%
# exploring data set
# identifying columns related to medical codexes
icd_codes = data['ICD_CODE']
drg_codes = data['DRG_CODE']
hspcs_codes = data['HCPSC_CODE']
#ICD_CODE does not exist
#there are several codes that begin with ICD in the data, but then followed by other letters.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ICD_'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-853cf0ce3bf6> in <cell line: 3>()
#       1 # exploring data set
# ...

# %%
## list each of the codes to be used as my 8 unique codes for the homework assignment
## followed by the frequency calculation
## codes that contained -several- null values from the top and bottom 5 have already been excluded from the analysis as per searches listed above

# %%
df.CLM_ID
# Out:
# 0       -10000930037831
# 1       -10000930038030
# 2       -10000930038031
# 3       -10000930038162
# 4       -10000930038162
#               ...
# 58061   -10000931485965
# 58062   -10000931485967
# 58063   -10000931485969
# 58064   -10000931485971
# 58065   -10000931486024
# Name: CLM_ID, Length: 58066, dtype: int64

# %%
count = df.CLM_ID.unique()
len(count)
# Out:
# 20867

# %%
## Testing value counts
df['CLM_ID'].value_counts()
# Out:
# CLM_ID
# -10000930775141    46
# -10000930521375    34
# -10000930487748    34
# -10000931409722    32
# -10000931016403    30
#                    ..
# -10000930629710     1
# -10000930629711     1
# -10000930629713     1
# -10000930629720     1
# -10000931486024     1
# Name: count, Length: 20867, dtype: int64

# %%
df['CLM_ID'].describe()
# CLM_ID label means Claim ID
# This is the unique identification number for the claim
# Type: CHAR
# There are 20867 unique Claim ID numbers in the data set
# Out:
# count    5.806600e+04
# mean    -1.000093e+13
# std      4.213611e+05
# min     -1.000093e+13
# 25%     -1.000093e+13
# 50%     -1.000093e+13
# 75%     -1.000093e+13
# max     -1.000093e+13
# Name: CLM_ID, dtype: float64

# %%
df.dtypes
# Out:
# BENE_ID                          int64
# CLM_ID                           int64
# NCH_NEAR_LINE_REC_IDENT_CD      object
# NCH_CLM_TYPE_CD                  int64
# CLM_FROM_DT                     object
#                                 ...
# CLM_UNCOMPD_CARE_PMT_AMT       float64
# CLM_LINE_NUM                     int64
# REV_CNTR                         int64
# HCPCS_CD                        object
# REV_CNTR_DDCTBL_COINSRNC_CD    float64
# Length: 197, dtype: object

# %%
df.CLM_UTLZTN_DAY_CNT
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 58061    6
# 58062    0
# 58063    0
# 58064    3
# 58065    0
# Name: CLM_UTLZTN_DAY_CNT, Length: 58066, dtype: int64

# %%
count = df.CLM_UTLZTN_DAY_CNT.unique()
len(count)
# Out:
# 45

# %%
df['CLM_UTLZTN_DAY_CNT'].value_counts()
# Out:
# CLM_UTLZTN_DAY_CNT
# 0      42934
# 1       3455
# 2       1145
# 4       1090
# 5       1052
# 6       1034
# 3        896
# 9        891
# 7        872
# 8        750
# 10       714
# 14       641
# 12       603
# 13       596
# 11       514
# 18       166
# 15       152
# 16       115
# 25        79
# 21        77
# 17        74
# 22        55
# 23        34
# 20        33
# 29        32
# 19        11
# 32         7
# 26         5
# 24         5
# 36         5
# 27         4
# 28         4
# 31         3
# 64         2
# 39         2
# 34         2
# 104        2
# 30         2
# 45         2
# 43         1
# 40         1
# 50         1
# 37         1
# 47         1
# 33         1
# Name: count, dtype: int64

# %%
df['CLM_UTLZTN_DAY_CNT'].describe()
## CLM_UTLZTN_DAY_CNT means Claim Pass Thru Per Diem Amount
## Medicare establishes a daily payment amount to reimburse IPPS hospitals for certain 'pass-through' expenses
## Type: NUM
## There are 45 unique amounts in the data set
# Out:
# count    58066.000000
# mean         1.700272
# std          4.002500
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max        104.000000
# Name: CLM_UTLZTN_DAY_CNT, dtype: float64

# %%
df.CLM_FROM_DT
# Out:
# 0        25-Mar-2015
# 1        24-Sep-2015
# 2        09-May-2017
# 3        14-Jan-2017
# 4        14-Jan-2017
#             ...
# 58061    08-Jan-2020
# 58062    23-Oct-2020
# 58063    22-Aug-2021
# 58064    13-Sep-2021
# 58065    11-Jun-2017
# Name: CLM_FROM_DT, Length: 58066, dtype: object

# %%
count = df.CLM_FROM_DT.unique()
len(count)
# Out:
# 2914

# %%
df['CLM_FROM_DT'].value_counts()
# Out:
# CLM_FROM_DT
# 09-Jan-2021    101
# 29-Oct-2022     88
# 15-Jan-2023     80
# 20-Jan-2021     79
# 02-Mar-2022     74
#               ...
# 05-Jul-2015      1
# 23-Jul-2015      1
# 25-Mar-2018      1
# 04-Mar-2015      1
# 01-Mar-2016      1
# Name: count, Length: 2914, dtype: int64

# %%
df['CLM_FROM_DT'].describe()
## CLM_FROM_DT means Claim from Date
## The first day on the billing statement covering services rendered to the beneficiary (aka "Statement covers from Date")
## Type: DATE
## 2914 unique claim from dates
# Out:
# count           58066
# unique           2914
# top       09-Jan-2021
# freq              101
# Name: CLM_FROM_DT, dtype: object

# %%
df.CLM_PMT_AMT
# Out:
# 0          96.65
# 1        6311.88
# 2        8545.72
# 3        1014.85
# 4        1014.85
#           ...
# 58061     166.97
# 58062     166.97
# 58063     166.97
# 58064     166.97
# 58065     166.97
# Name: CLM_PMT_AMT, Length: 58066, dtype: float64

# %%
count = df.CLM_PMT_AMT.unique()
len(count)
# Out:
# 10341

# %%
df['CLM_PMT_AMT'].value_counts()
# Out:
# CLM_PMT_AMT
# 950.31      529
# 166.97      525
# 1140.09     524
# 1358.56     473
# 108.86      463
#            ...
# 811.96        1
# 820.78        1
# 507.90        1
# 5527.34       1
# 14240.89      1
# Name: count, Length: 10341, dtype: int64

# %%
df['CLM_PMT_AMT'].describe()
## CLM_PMT_AMT means Claim (Medicare) Payment Amount
## The Medicare claim payment amount
## Type: NUM
## There are 10341 unique claim payment amounts
# Out:
# count     58066.000000
# mean      13638.307734
# std       35993.907780
# min          62.440000
# 25%         945.370000
# 50%        1481.715000
# 75%        9932.040000
# max      598716.310000
# Name: CLM_PMT_AMT, dtype: float64

# %%
df.CLM_TOT_CHRG_AMT
# Out:
# 0          96.65
# 1        6311.88
# 2        8545.72
# 3        1014.85
# 4        1014.85
#           ...
# 58061     166.97
# 58062     166.97
# 58063     166.97
# 58064     166.97
# 58065     166.97
# Name: CLM_TOT_CHRG_AMT, Length: 58066, dtype: float64

# %%
count = df.CLM_TOT_CHRG_AMT .unique()
len(count)
# Out:
# 10341

# %%
df['CLM_TOT_CHRG_AMT'].value_counts()
# Out:
# CLM_TOT_CHRG_AMT
# 950.31      529
# 166.97      525
# 1140.09     524
# 1358.56     473
# 108.86      463
#            ...
# 811.96        1
# 820.78        1
# 507.90        1
# 5527.34       1
# 14240.89      1
# Name: count, Length: 10341, dtype: int64

# %%
df['CLM_TOT_CHRG_AMT'].describe()
## CLM_TOT_CHRG_AMT means Claim Total Charge Amount
## The total charges for all services included on the institutional claim
## Type: NUM
## There are 10341 unique claim total charge amounts
# Out:
# count     58066.000000
# mean      13638.307734
# std       35993.907780
# min          62.440000
# 25%         945.370000
# 50%        1481.715000
# 75%        9932.040000
# max      598716.310000
# Name: CLM_TOT_CHRG_AMT, dtype: float64

# %%
df.PRNCPAL_DGNS_CD
# Out:
# 0         S134XX
# 1          Z3480
# 2         T7432X
# 3         S8290X
# 4         S8290X
#           ...
# 58061    T50901A
# 58062    T50901A
# 58063    T50901A
# 58064    T50901A
# 58065     S93409
# Name: PRNCPAL_DGNS_CD, Length: 58066, dtype: object

# %%
count = df.PRNCPAL_DGNS_CD.unique()
len(count)
# Out:
# 190

# %%
df['PRNCPAL_DGNS_CD'].value_counts()
# Out:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64

# %%
df['PRNCPAL_DGNS_CD'].describe()
## PRNCPAL_DGNS_CD means Claim Principal Diagnosis Code
## The diagnosis code identifying the diagnosis, condition, problem, or other reason for the admission/encounter/visit shown in the
## medical record to be chiefly responsible for the services provided
## Type: CHAR
## There are 190 unique claim principal diagnosis codes
# Out:
# count     58066
# unique      190
# top        Z733
# freq      11469
# Name: PRNCPAL_DGNS_CD, dtype: object

# %%
df.ICD_DGNS_CD1
# Out:
# 0        S134XX
# 1        T7432X
# 2        T7432X
# 3        S8290X
# 4        S8290X
#           ...
# 58061    T7432X
# 58062      Z733
# 58063      Z608
# 58064      Z608
# 58065    S93409
# Name: ICD_DGNS_CD1, Length: 58066, dtype: object

# %%
count = df.ICD_DGNS_CD1.unique()
len(count)
# Out:
# 231

# %%
df['ICD_DGNS_CD1'].value_counts()
# Out:
# ICD_DGNS_CD1
# Z733      13031
# Z608       8227
# T7432X     3727
# Z604       3537
# Z940       2858
#           ...
# T8611         1
# E1141         1
# E11610        1
# I071          1
# M069          1
# Name: count, Length: 231, dtype: int64

# %%
df['ICD_DGNS_CD1'].describe()
## ICD_DGNS_CD1 means Claim Diagnosis Code
## The diagnosis code identifying the beneficiary's diagnosis
## Type: CHAR
## There are 231 unique claim diagnosis codes
# Out:
# count     58066
# unique      231
# top        Z733
# freq      13031
# Name: ICD_DGNS_CD1, dtype: object

# %%
df.HCPCS_CD
# Out:
# 0        99221
# 1        99221
# 2        99024
# 3        73610
# 4        29515
#          ...
# 58061    99221
# 58062    99221
# 58063    99221
# 58064    99221
# 58065    99221
# Name: HCPCS_CD, Length: 58066, dtype: object

# %%
count = df.HCPCS_CD.unique()
len(count)
# Out:
# 106

# %%
df['HCPCS_CD'].value_counts()
# Out:
# HCPCS_CD
# 99221    8298
# G0444    7990
# 96156    5080
# 99408    4196
# 99495    3867
#          ...
# S9361       1
# S9355       1
# S9374       1
# S9377       1
# G9829       1
# Name: count, Length: 106, dtype: int64

# %%
df['HCPCS_CD'].describe()
## HCPCS_CD means Healthcare Common Procedure Coding System (HSPCS) Code
## The healthcare common procedure coding system (HSPCS) is a collection of codes that represent procedures, supplies, products, and services which may be provided to Medicare beneficiaries and to
## individuals enrolled in private health insurance programs. The codes are divided into three levels, or groups.
## Type: CHAR
## There are 106 unique healthcare common prodcedure coding system codes
# Out:
# count     58066
# unique      106
# top       99221
# freq       8298
# Name: HCPCS_CD, dtype: object

# %%
df.ICD_DGNS_CD1
icd_codes = data['ICD_DGNS_CD1']
missing_icd = icd_codes.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ICD_DGNS_CD1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-675acbdb7d7f> in <cell line: 2>()
#       1 df.ICD_DGNS_CD1
# ----> 2 icd_codes = data['ICD_DGNS_CD1']
# ...

# %%
missing_drg = drg_codes.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-a0001c6572db> in <cell line: 1>()
# ----> 1 missing_drg = drg_codes.isnull().sum()
#
# NameError: name 'drg_codes' is not defined

# %%
print("top 5 most common ICD Codes:\n")
# Out:
# top 5 most common ICD Codes:

# %%
codex_colums = ['CLM_ID',
                'CLM_UTLZTN_DAY_CNT',
                'CLM_FROM_DT',
                'CLM_PMT_AMT',
                'CLM_TOT_CHRG_AMT',
                'PRNCPAL_DGNS_CD',
                'ICD_DGNS_CD1',
                'HCPCS_CD' ,
]
for column in codex_colums:
    print(f"Frequency counts for {column}:")
    print(df[column].value_counts())
    print("\n")
# Out:
# Frequency counts for CLM_ID:
# CLM_ID
# -10000930775141    46
# -10000930521375    34
# -10000930487748    34
# -10000931409722    32
# -10000931016403    30
#                    ..
# -10000930629710     1
# -10000930629711     1
# -10000930629713     1
# -10000930629720     1
# -10000931486024     1
# Name: count, Length: 20867, dtype: int64
#
#
# Frequency counts for CLM_UTLZTN_DAY_CNT:
# CLM_UTLZTN_DAY_CNT
# 0      42934
# 1       3455
# 2       1145
# 4       1090
# 5       1052
# 6       1034
# 3        896
# 9        891
# 7        872
# 8        750
# 10       714
# 14       641
# 12       603
# 13       596
# 11       514
# 18       166
# 15       152
# 16       115
# 25        79
# 21        77
# 17        74
# 22        55
# 23        34
# 20        33
# 29        32
# 19        11
# 32         7
# 26         5
# 24         5
# 36         5
# 27         4
# 28         4
# 31         3
# 64         2
# 39         2
# 34         2
# 104        2
# 30         2
# 45         2
# ...

# %%
##comment to test
